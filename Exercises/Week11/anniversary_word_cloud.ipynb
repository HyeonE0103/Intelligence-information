# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib
import time

# %%
url = "https://kin.naver.com/search/list.naver?query=%EB%B9%BC%EB%B9%BC%EB%A1%9C%EB%8D%B0%EC%9D%B4&page=1"
html = urlopen(url)

soup = BeautifulSoup(html, "html.parser")

# %%
docs = soup.find("ul", {"class": "basic1"}).find_all("li")

for doc in docs:
    ans = doc.find_all("dd")[1]
    print(ans)
# Out:
# <dd>빼빼로와 <b>빼빼로데이</b> 라는 단어는 특정기업의 상표권등록이 되어있는것으로 알고있습니다. 그런데 <b>빼빼로데이</b>라는 단어는 식품이 아닌 다른 제품에(예를들면 볼펜류) 상표권... </dd>
# <dd>트와이스 걸 그룹이 <b>빼빼로 데이</b> 지나고 다음 날 새 앨범을 내는 이유는 무엇인지요?  굳이 <b>빼빼로데이</b>라는 건 의식해서 다음날 앨범을 내거나 <b>빼빼로데이</b>를 의식해서 그날... </dd>
# <dd>작년에 남편한테 <b>빼빼로데이</b>선물로 스킨,로션,에센스... 올해 <b>빼빼로데이</b>선물은 올인원 제품으로 할까하는데... 부탁드려요  <b>빼빼로데이</b>선물 할 시즌이 다가 오긴 하네요.ㅎㅎ... </dd>
# <dd>... 하는데 <b>빼빼로데이</b>때 빼빼로 하나 선물해줄까요?  안녕하세요~! 혹시 썸단계 이신건가요? 달달한 <b>빼빼로데이</b>... 저는 이번 <b>빼빼로데이</b>에 여자친구가 좋아하는 인형하고... </dd>
# <dd>대학생들 <b>빼빼로데이</b>날 빼빼로 학교에 가져오나요  누구 줄사람있으면 주고 없으면 안 챙겨오고 오늘 <b>빼빼로데이</b>네 하고 매점가서 그날 구매해서 주기도 하고 먹기도 하고 합니다</dd>
# <dd>부산에 있는 남자친구 회사에 <b>빼빼로데이</b>에 맞춰... 지인들에게도 추천드리는 <b>빼빼로데이</b>선물 BEST... 러블리 로즈베어 빼빼로6개입 빼빼로선물세트 <b>빼빼로데이</b>, 2.... </dd>
# <dd><b>빼빼로 데이</b>에 친구들은 저에게 수제 빼빼로를 만들어준다고 하는데 저도 친구들처럼... <b>빼빼로 데이</b>에 친구들에게 선물하면 괜찮은 수제 빼빼로를 몇 가지 링크 걸어드릴 테니... </dd>
# <dd>제가 이 질문을 하는 시간 또한 11월 11일 인데 혹시 11월 11일이 <b>빼빼로 데이</b>인 이유가... DAY) <b>빼빼로 데이</b> - 대한민국 앙골라 독립기념일 - 앙골라 영령 기념일 - 영연방... </dd>
# <dd><b>빼빼로데이</b>때 저는 남친 줄려고 선물세트를 한박스 샀는데 남자친구는 만약에 빼빼로... 굳이 <b>빼빼로데이</b> 때 빼빼로 갯수로 마음을 확인하지 않으셨으면 좋겠습니다^^</dd>
# <dd>곧 <b>빼빼로 데이</b>인데 평범한거 주기 싫어서 프레첼에 초코 묻혀서 포장해서 친구들 주려고 합니다 근데 미리 구매를 못해서 이마트에 가서 쟤료를 사려고 해요 지금... </dd>

# %%
tmp_list = []

for doc in docs:
    ans = doc.find_all("dd")[1]
    tmp_list.append(ans.text.strip())
    
print(tmp_list[:3])
# Out:
# ['빼빼로와 빼빼로데이 라는 단어는 특정기업의 상표권등록이 되어있는것으로 알고있습니다. 그런데 빼빼로데이라는 단어는 식품이 아닌 다른 제품에(예를들면 볼펜류) 상표권...', '트와이스 걸 그룹이 빼빼로 데이 지나고 다음 날 새 앨범을 내는 이유는 무엇인지요?  굳이 빼빼로데이라는 건 의식해서 다음날 앨범을 내거나 빼빼로데이를 의식해서 그날...', '작년에 남편한테 빼빼로데이선물로 스킨,로션,에센스... 올해 빼빼로데이선물은 올인원 제품으로 할까하는데... 부탁드려요  빼빼로데이선물 할 시즌이 다가 오긴 하네요.ㅎㅎ...']

# %%
from tqdm.notebook import tqdm

tmp_list = []

for i in tqdm(range(1, 10)):
    url = "https://kin.naver.com/search/list.naver?query=%EB%B9%BC%EB%B9%BC%EB%A1%9C%EB%8D%B0%EC%9D%B4&page="+str(i)
    html = urlopen(url)
    
    soup = BeautifulSoup(html, "html.parser")
    docs = soup.find("ul", {"class": "basic1"}).find_all("li")
    
    for doc in docs:
        ans = doc.find_all("dd")[1]
        tmp_list.append(ans.text.strip())
        
    time.sleep(0.5)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
ko_doc = '\n'.join(tmp_list)
print(ko_doc[:500])
# Out:
# 빼빼로와 빼빼로데이 라는 단어는 특정기업의 상표권등록이 되어있는것으로 알고있습니다. 그런데 빼빼로데이라는 단어는 식품이 아닌 다른 제품에(예를들면 볼펜류) 상표권...
# 트와이스 걸 그룹이 빼빼로 데이 지나고 다음 날 새 앨범을 내는 이유는 무엇인지요?  굳이 빼빼로데이라는 건 의식해서 다음날 앨범을 내거나 빼빼로데이를 의식해서 그날...
# 작년에 남편한테 빼빼로데이선물로 스킨,로션,에센스... 올해 빼빼로데이선물은 올인원 제품으로 할까하는데... 부탁드려요  빼빼로데이선물 할 시즌이 다가 오긴 하네요.ㅎㅎ...
# ... 하는데 빼빼로데이때 빼빼로 하나 선물해줄까요?  안녕하세요~! 혹시 썸단계 이신건가요? 달달한 빼빼로데이... 저는 이번 빼빼로데이에 여자친구가 좋아하는 인형하고...
# 대학생들 빼빼로데이날 빼빼로 학교에 가져오나요  누구 줄사람있으면 주고 없으면 안 챙겨오고 오늘 빼빼로데이네 하고 매점가서 그날 구매해서 주기도 하고 먹기도 하고 합니다
# 부산에 있는 남자친구 회사에 빼빼로

# %%
print(len(ko_doc))
# Out:
# 8526

# %%
import time

start = time.time()
ko_doc_noun = okt.nouns(ko_doc)
print(time.time()-start)
# Out:
# 2.881229877471924

# %%
from collections import Counter

count_noun = Counter(ko_doc_noun)

# %%
count_noun.most_common(20)
# Out:
# [('빼빼로데이', 153),
#  ('빼빼로', 105),
#  ('선물', 80),
#  ('데이', 43),
#  ('추천', 25),
#  ('때', 24),
#  ('세트', 18),
#  ('저', 16),
#  ('친구', 16),
#  ('여자친구', 15),
#  ('남자친구', 14),
#  ('제', 13),
#  ('날', 11),
#  ('이번', 11),
#  ('남친', 11),
#  ('관련', 10),
#  ('요', 9),
#  ('과자', 8),
#  ('오늘', 7),
#  ('아래', 7)]

# %%
stopword_list = ['빼빼로데이', '빼빼로', '데이']

for word in count_noun:
    if len(word) == 1:
        stopword_list.append(word)
        
stopword_list[-5:]
# Out:
# ['쌤', '콩', '톡', '맛', '상']

# %%
for stopword in stopword_list:
    if stopword in count_noun:
        count_noun.pop(stopword)

# %%
from wordcloud import WordCloud

wc_noun = WordCloud(background_color='white', max_words=200, 
                     font_path=r'C:\Windows\Fonts\NanumGothic.ttf')
wc_noun = wc_noun.generate_from_frequencies(count_noun)

import matplotlib.pyplot as plt
plt.imshow(wc_noun, interpolation="bilinear")
plt.axis("off")
plt.show()

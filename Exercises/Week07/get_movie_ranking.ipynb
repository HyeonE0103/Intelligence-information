# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=pnt&date=20211011"
html = urlopen(url)

soup = BeautifulSoup(html.read(), "html.parser")

title_list = soup.find_all('div', {'class':'tit5'})
point_list = soup.find_all('td', {'class':'point'})

for title in title_list:
#     print(title.text.strip(' \n'))
    print(title.get_text(strip='\n'))
for point in point_list:
    print(point.text)
# Out:
# 밥정
# 그린 북
# 가버나움
# 디지몬 어드벤처 라스트 에볼루션 : 인연
# 원더
# 베일리 어게인
# 아일라
# 먼 훗날 우리
# 그대, 고맙소 : 김호중 생애 첫 팬미팅 무비
# 당갈
# 극장판 바이올렛 에버가든
# 포드 V 페라리
# 주전장
# 쇼생크 탈출
# 터미네이터 2:오리지널
# 나 홀로 집에
# 클래식
# 라이언 일병 구하기
# 덕구
# 월-E
# 보헤미안 랩소디
# 사운드 오브 뮤직
# 빽 투 더 퓨쳐
# 잭 스나이더의 저스티스 리그
# 포레스트 검프
# 위대한 쇼맨
# 글래디에이터
# 타이타닉
# 헬프
# 인생은 아름다워
# 매트릭스
# 살인의 추억
# 센과 치히로의 행방불명
# 가나의 혼인잔치: 언약
# 토이 스토리 3
# 헌터 킬러
# 캐스트 어웨이
# 집으로...
# 태극권
# 반지의 제왕: 왕의 귀환
# 죽은 시인의 사회
# 히든 피겨스
# 어벤져스: 엔드게임
# 알라딘
# 레옹
# 쉰들러 리스트
# 아이 캔 스피크
# 동주
# 클레멘타인
# 안녕 베일리
# 9.63
# 9.59
# 9.59
# 9.54
# 9.53
# 9.52
# 9.51
# 9.50
# 9.49
# 9.49
# 9.49
# 9.48
# 9.47
# 9.45
# 9.44
# 9.43
# 9.43
# 9.43
# 9.43
# 9.42
# 9.42
# 9.42
# 9.41
# 9.41
# 9.41
# 9.41
# 9.41
# 9.40
# 9.40
# 9.40
# 9.40
# 9.40
# 9.40
# 9.39
# 9.39
# 9.39
# 9.39
# 9.38
# 9.38
# 9.38
# 9.38
# 9.38
# 9.38
# 9.38
# 9.38
# 9.37
# 9.37
# 9.37
# 9.37
# 9.37

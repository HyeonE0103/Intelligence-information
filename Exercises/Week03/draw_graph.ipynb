# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.title('범례')

plt.plot([25,10,5,0], color='skyblue', linestyle='--', marker='v', label="범례1")
plt.plot([10,15,20,25], color='pink', ls=':', marker='o', label="범례2")

plt.legend(loc=1)
plt.show()

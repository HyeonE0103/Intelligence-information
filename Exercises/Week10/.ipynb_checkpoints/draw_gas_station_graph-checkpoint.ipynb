# %%
from glob import glob

# %%
glob('지역*.xls')
# Out:
# ['지역_위치별(주유소) (1).xls',
#  '지역_위치별(주유소) (2).xls',
#  '지역_위치별(주유소) (3).xls',
#  '지역_위치별(주유소) (4).xls',
#  '지역_위치별(주유소) (5).xls',
#  '지역_위치별(주유소) (6).xls',
#  '지역_위치별(주유소) (7).xls',
#  '지역_위치별(주유소) (8).xls',
#  '지역_위치별(주유소) (9).xls',
#  '지역_위치별(주유소).xls']

# %%
station_files = glob('지역*.xls')
station_files
# Out:
# ['지역_위치별(주유소) (1).xls',
#  '지역_위치별(주유소) (2).xls',
#  '지역_위치별(주유소) (3).xls',
#  '지역_위치별(주유소) (4).xls',
#  '지역_위치별(주유소) (5).xls',
#  '지역_위치별(주유소) (6).xls',
#  '지역_위치별(주유소) (7).xls',
#  '지역_위치별(주유소) (8).xls',
#  '지역_위치별(주유소) (9).xls',
#  '지역_위치별(주유소).xls']

# %%
import pandas as pd

tmp_list = []

for file_name in station_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_list.append(tmp)

tmp_list[0]
# Out:
#        지역                     상호                       주소      상표  \
# 0   인천광역시      지에스칼텍스(주)계산신도시주유소          인천 계양구 봉오대로 942   GS칼텍스
# 1   인천광역시       SK에너지(주) 행복날개주유소     인천 계양구 계양대로 93 (작전동)   SK에너지
# 2   인천광역시                원천제2주유소           인천 계양구 벌말로 295   알뜰주유소
# 3   인천광역시                  계현주유소    인천 계양구 장제로 1263 (장기동)   SK에너지
# 4   인천광역시                  상야주유소        인천 계양구 벌말로584번길 1   S-OIL
# 5   인천광역시                 동양동주유소     인천 계양구 벌말로 328 (동양동)   GS칼텍스
# 6   인천광역시         (주)스타에너지상사 계양점           인천 계양구 벌말로 545   GS칼텍스
# 7   인천광역시            (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL
# 8   인천광역시  KH에너지(주)직영 에이원주유소(셀프)      인천 계양구 벌말로 583(하야동)   SK에너지
# 9   인천광역시                  럭키주유소           인천 계양구 벌말로 614  현대오일뱅크
# 10  인천광역시                  그린에너지            인천 계양구 솔고개길 2   S-OIL
# 11  인천광역시                   오주유소          인천 계양구 아나지로 553  현대오일뱅크
# 12  인천광역시                  미래주유소    인천 계양구 경명대로 966 (계산동)   SK에너지
# 13  인천광역시                  양정주유소    인천 계양구 아나지로 597 (서운동)   알뜰주유소
# 14  인천광역시          서울석유(주) 태경주유소          인천 계양구 아나지로 554   SK에너지
# 15  인천광역시           동일석유(주)동일주유소    인천 계양구 아나지로 283 (작전동)   SK에너지
# 16  인천광역시                  명품주유소    인천 계양구 경명대로 971 (계산동)   GS칼텍스
# 17  인천광역시                  현대주유소    인천 계양구 아나지로 344 (작전동)  현대오일뱅크
# 18  인천광역시                  믿음주유소    인천 계양구 아나지로 557 (서운동)   S-OIL
# 19  인천광역시                  박촌주유소    인천 계양구 장제로 1021 (박촌동)  현대오일뱅크
# 20  인천광역시  현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크
# 21  인천광역시          씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL
# 22  인천광역시                  미담주유소          인천 계양구 계양대로 108   SK에너지
# 23  인천광역시    현대오일뱅크(주)직영 유화셀프주유소    인천 계양구 아나지로 240 (효성동)  현대오일뱅크
# 24  인천광역시            토마토주유소(오류점)   인천 계양구 장제로 1456  (오류동)   S-OIL
# 25  인천광역시              임학주유소(셀프)   인천 계양구 경명대로 1161 (임학동)   SK에너지
# 26  인천광역시          삼미상사(주)북인천주유소   인천 계양구 경명대로 1082 (계산동)   SK에너지
# 27  인천광역시          서일석유(주) 갈현주유소    인천 계양구  드림로 764 (갈현동)   GS칼텍스
# 28  인천광역시        SK에너지(주) 하나원주유소    인천 계양구 아나지로 426 (작전동)   SK에너지
# 29  인천광역시               (주)거보주유소    인천 계양구 아나지로 130 (효성동)   GS칼텍스
# 30  인천광역시               영부에너지주유소    인천 계양구 아나지로 148 (효성동)   SK에너지
# 31  인천광역시            주식회사 보라미주유소       인천 계양구 장기로 7 (장기동)  현대오일뱅크
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0   032-543-8951    Y  1792  1642  1475  1100
# 1   032-542-9601    Y     -  1660  1488     -
# 2   032-555-9143    Y     -  1729  1529     -
# 3   032-514-5141    Y     -  1785  1585  1150
# 4   032-555-7242    Y     -  1787  1567  1150
# 5   032-513-5831    Y     -  1787  1567     -
# 6   032-543-5104    Y     -  1787  1567     -
# 7   032-542-3154    Y     -  1787  1567     -
# 8   032-543-6395    Y     -  1787  1567  1150
# 9   032-553-5675    N     -  1787  1567     -
# 10  032-584-5189    N     -  1796  1556  1200
# 11  032-554-5189    N     -  1797  1577  1300
# 12  032-553-0001    Y     -  1797  1547  1100
# 13  032-555-4749    Y     -  1797  1577     -
# 14  032-555-5189    Y     -  1797  1587     -
# 15  032-542-0052    Y     -  1797  1587  1150
# 16  032-546-0777    Y     -  1797  1567     -
# 17  032-542-1558    Y     -  1797  1587     -
# 18  032-553-2525    Y     -  1797  1577     -
# 19  032-519-9922    Y     -  1797  1567     -
# 20  032-552-5185    Y  2009  1805  1595     -
# 21  032-554-2994    Y     -  1807  1607     -
# 22  032-556-5182    Y     -  1807  1597  1300
# 23  032-553-5189    Y  2019  1807  1597  1150
# 24  032-552-5189    Y     -  1817  1597     -
# 25  032-548-5189    Y     -  1817  1617     -
# 26  032-545-2421    Y     -  1817  1617     -
# 27  032-513-8903    N     -  1818  1597     -
# 28  032-544-5151    N     -  1824  1604     -
# 29  032-545-5145    N     -  1829  1605  1198
# 30  032-548-5501    Y     -  1829  1585  1150
# 31  032-541-2175    Y     -     -  1595  1150

# %%
stations = pd.concat(tmp_list)
stations.shape
# Out:
# (328, 10)

# %%
 stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 328 entries, 0 to 28
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      328 non-null    object
#  1   상호      328 non-null    object
#  2   주소      328 non-null    object
#  3   상표      328 non-null    object
#  4   전화번호    328 non-null    object
#  5   셀프여부    328 non-null    object
#  6   고급휘발유   328 non-null    object
#  7   휘발유     328 non-null    object
#  8   경유      328 non-null    object
#  9   실내등유    328 non-null    object
# dtypes: object(10)
# memory usage: 28.2+ KB

# %%
stations.head()
# Out:
#       지역                 상호                     주소     상표          전화번호 셀프여부  \
# 0  인천광역시  지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스  032-543-8951    Y
# 1  인천광역시   SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지  032-542-9601    Y
# 2  인천광역시            원천제2주유소         인천 계양구 벌말로 295  알뜰주유소  032-555-9143    Y
# 3  인천광역시              계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지  032-514-5141    Y
# 4  인천광역시              상야주유소      인천 계양구 벌말로584번길 1  S-OIL  032-555-7242    Y
#
#   고급휘발유   휘발유    경유  실내등유
# 0  1792  1642  1475  1100
# 1     -  1660  1488     -
# 2     -  1729  1529     -
# 3     -  1785  1585  1150
# 4     -  1787  1567  1150

# %%
stations_sel = stations.loc[:,['상호','주소','상표','셀프여부','휘발유']]
stations_sel
# Out:
#                    상호                     주소     상표 셀프여부   휘발유
# 0   지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642
# 1    SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660
# 2             원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729
# 3               계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785
# 4               상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787
# ..                ...                    ...    ...  ...   ...
# 24              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858
# 25              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859
# 26           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889
# 27              양갑주유소    인천 강화군 교동면 교동서로 274  SK에너지    N     -
# 28              한국주유소     인천 강화군 선원면 중앙로 445   자가상표    N     -
#
# [328 rows x 5 columns]

# %%
stations_sel.columns = ['주유소','주소','상표','셀프여부','가격']
stations_sel
# Out:
#                   주유소                     주소     상표 셀프여부    가격
# 0   지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642
# 1    SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660
# 2             원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729
# 3               계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785
# 4               상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787
# ..                ...                    ...    ...  ...   ...
# 24              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858
# 25              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859
# 26           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889
# 27              양갑주유소    인천 강화군 교동면 교동서로 274  SK에너지    N     -
# 28              한국주유소     인천 강화군 선원면 중앙로 445   자가상표    N     -
#
# [328 rows x 5 columns]

# %%
gu_list = []


for address in stations['주소']:
    address_gu = address.split()[1]
    gu_list.append(address_gu)

stations_sel['군/구'] = gu_list
stations_sel
# Out:
#                   주유소                     주소     상표 셀프여부    가격  군/구
# 0   지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642  계양구
# 1    SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660  계양구
# 2             원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729  계양구
# 3               계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785  계양구
# 4               상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787  계양구
# ..                ...                    ...    ...  ...   ...  ...
# 24              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858  강화군
# 25              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859  강화군
# 26           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889  강화군
# 27              양갑주유소    인천 강화군 교동면 교동서로 274  SK에너지    N     -  강화군
# 28              한국주유소     인천 강화군 선원면 중앙로 445   자가상표    N     -  강화군
#
# [328 rows x 6 columns]

# %%
stations_sel['군/구'].unique()
# Out:
# array(['계양구', '남동구', '동구', '미추홀구', '남구', '부평구', '서구', '연수구', '옹진군', '중구',
#        '강화군'], dtype=object)

# %%
#예외 처리하기
stations_sel.query("가격 == '-'")
# Out:
#                    주유소                     주소      상표 셀프여부 가격   군/구
# 31         주식회사 보라미주유소     인천 계양구 장기로 7 (장기동)  현대오일뱅크    Y  -   계양구
# 44            원탑코리아주유소   인천 남동구 석정로 544 (간석동)   S-OIL    N  -   남동구
# 31          SK큰나무셀프주우소       인천 미추홀구 매소홀로 536   S-OIL    Y  -  미추홀구
# 32      에스지씨솔루션㈜ 인천1지점   인천 미추홀구 아암대로253번길 14   GS칼텍스    N  -  미추홀구
# 70  현대오일뱅크㈜직영 서인천셀프주유소    인천 서구 서곶로 346 (연희동)  현대오일뱅크    Y  -    서구
# 71      삼미상사(주)부광셀프주유소        인천 서구 봉수대로 1623   SK에너지    Y  -    서구
# 72        원당에너지주유소/충전소        인천 서구 원당대로 1025   SK에너지    N  -    서구
# 17    지에스칼텍스(주)연수시티주유소  인천 연수구 먼우금로 200 (연수동)   GS칼텍스    Y  -   연수구
# 37        동일석유(주)성신주유소          인천 중구 인중로 154   SK에너지    N  -    중구
# 27               양갑주유소    인천 강화군 교동면 교동서로 274   SK에너지    N  -   강화군
# 28               한국주유소     인천 강화군 선원면 중앙로 445    자가상표    N  -   강화군

# %%
stations_sel = stations_sel.query("가격 != '-'")
stations_sel
# Out:
#                   주유소                     주소     상표 셀프여부    가격  군/구
# 0   지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642  계양구
# 1    SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660  계양구
# 2             원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729  계양구
# 3               계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785  계양구
# 4               상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787  계양구
# ..                ...                    ...    ...  ...   ...  ...
# 22           (주)유성주유소   인천 강화군 하점면 강화대로 1114  SK에너지    N  1830  강화군
# 23              아름주유소     인천 강화군 선원면 중앙로 150  GS칼텍스    Y  1847  강화군
# 24              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858  강화군
# 25              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859  강화군
# 26           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889  강화군
#
# [317 rows x 6 columns]

# %%
#가격을 숫자(int)로 변경

price_list = []

for price in stations_sel['가격']:
    price_new = int(price)
    price_list.append(price_new)
    
stations_sel['가격'] = price_list
stations_sel
# Out:
# <ipython-input-20-fa6fe12c45b8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_sel['가격'] = price_list
#                   주유소                     주소     상표 셀프여부    가격  군/구
# 0   지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642  계양구
# 1    SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660  계양구
# 2             원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729  계양구
# 3               계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785  계양구
# 4               상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787  계양구
# ..                ...                    ...    ...  ...   ...  ...
# 22           (주)유성주유소   인천 강화군 하점면 강화대로 1114  SK에너지    N  1830  강화군
# 23              아름주유소     인천 강화군 선원면 중앙로 150  GS칼텍스    Y  1847  강화군
# 24              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858  강화군
# 25              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859  강화군
# 26           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889  강화군
#
# [317 rows x 6 columns]

# %%
stations_sel = stations_sel.query("가격 != '-'").copy()
stations_sel
# Out:
#                   주유소                     주소     상표 셀프여부    가격  군/구
# 0   지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642  계양구
# 1    SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660  계양구
# 2             원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729  계양구
# 3               계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785  계양구
# 4               상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787  계양구
# ..                ...                    ...    ...  ...   ...  ...
# 22           (주)유성주유소   인천 강화군 하점면 강화대로 1114  SK에너지    N  1830  강화군
# 23              아름주유소     인천 강화군 선원면 중앙로 150  GS칼텍스    Y  1847  강화군
# 24              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858  강화군
# 25              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859  강화군
# 26           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889  강화군
#
# [317 rows x 6 columns]

# %%
#가격을 숫자(int)로 변경

price_list = []

for price in stations_sel['가격']:
    price_new = int(price)
    price_list.append(price_new)
    
stations_sel['가격'] = price_list
stations_sel
# Out:
#                   주유소                     주소     상표 셀프여부    가격  군/구
# 0   지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642  계양구
# 1    SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660  계양구
# 2             원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729  계양구
# 3               계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785  계양구
# 4               상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787  계양구
# ..                ...                    ...    ...  ...   ...  ...
# 22           (주)유성주유소   인천 강화군 하점면 강화대로 1114  SK에너지    N  1830  강화군
# 23              아름주유소     인천 강화군 선원면 중앙로 150  GS칼텍스    Y  1847  강화군
# 24              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858  강화군
# 25              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859  강화군
# 26           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889  강화군
#
# [317 rows x 6 columns]

# %%
stations_sel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주유소     317 non-null    object
#  1   주소      317 non-null    object
#  2   상표      317 non-null    object
#  3   셀프여부    317 non-null    object
#  4   가격      317 non-null    int64
#  5   군/구     317 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 17.3+ KB

# %%
stations_sel.reset_index(inplace=True)
stations_sel
# Out:
#      index                주유소                     주소     상표 셀프여부    가격  군/구
# 0        0  지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642  계양구
# 1        1   SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660  계양구
# 2        2            원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729  계양구
# 3        3              계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785  계양구
# 4        4              상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787  계양구
# ..     ...                ...                    ...    ...  ...   ...  ...
# 312     22           (주)유성주유소   인천 강화군 하점면 강화대로 1114  SK에너지    N  1830  강화군
# 313     23              아름주유소     인천 강화군 선원면 중앙로 150  GS칼텍스    Y  1847  강화군
# 314     24              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858  강화군
# 315     25              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859  강화군
# 316     26           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889  강화군
#
# [317 rows x 7 columns]

# %%
del stations_sel['index']
stations_sel
# Out:
#                    주유소                     주소     상표 셀프여부    가격  군/구
# 0    지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942  GS칼텍스    Y  1642  계양구
# 1     SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)  SK에너지    Y  1660  계양구
# 2              원천제2주유소         인천 계양구 벌말로 295  알뜰주유소    Y  1729  계양구
# 3                계현주유소  인천 계양구 장제로 1263 (장기동)  SK에너지    Y  1785  계양구
# 4                상야주유소      인천 계양구 벌말로584번길 1  S-OIL    Y  1787  계양구
# ..                 ...                    ...    ...  ...   ...  ...
# 312           (주)유성주유소   인천 강화군 하점면 강화대로 1114  SK에너지    N  1830  강화군
# 313              아름주유소     인천 강화군 선원면 중앙로 150  GS칼텍스    Y  1847  강화군
# 314              강화주유소    인천 강화군 강화읍 강화대로 390  SK에너지    N  1858  강화군
# 315              세광주유소     인천 강화군 선원면 중앙로 205  S-OIL    N  1859  강화군
# 316           백마외포리주유소    인천 강화군 내가면 중앙로 1301  S-OIL    N  1889  강화군
#
# [317 rows x 6 columns]

# %%
stations_sel_name = stations_sel.set_index('상표')
stations_sel_name
# Out:
#                      주유소                     주소 셀프여부    가격  군/구
# 상표
# GS칼텍스  지에스칼텍스(주)계산신도시주유소        인천 계양구 봉오대로 942    Y  1642  계양구
# SK에너지   SK에너지(주) 행복날개주유소   인천 계양구 계양대로 93 (작전동)    Y  1660  계양구
# 알뜰주유소            원천제2주유소         인천 계양구 벌말로 295    Y  1729  계양구
# SK에너지              계현주유소  인천 계양구 장제로 1263 (장기동)    Y  1785  계양구
# S-OIL              상야주유소      인천 계양구 벌말로584번길 1    Y  1787  계양구
# ...                  ...                    ...  ...   ...  ...
# SK에너지           (주)유성주유소   인천 강화군 하점면 강화대로 1114    N  1830  강화군
# GS칼텍스              아름주유소     인천 강화군 선원면 중앙로 150    Y  1847  강화군
# SK에너지              강화주유소    인천 강화군 강화읍 강화대로 390    N  1858  강화군
# S-OIL              세광주유소     인천 강화군 선원면 중앙로 205    N  1859  강화군
# S-OIL           백마외포리주유소    인천 강화군 내가면 중앙로 1301    N  1889  강화군
#
# [317 rows x 5 columns]

# %%
#matplostlib 설정하기
import matplotlib.pyplot as plt

plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.style.use("ggplot")

stations_sel.boxplot(column='가격',by='셀프여부',figsize=(12,8))
# Out:
# <AxesSubplot:title={'center':'가격'}, xlabel='셀프여부'>

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.boxplot(x="상표",y="가격",hue="셀프여부",data=stations_sel,palette="Set3")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.boxplot(x="상표",y="가격",hue="셀프여부",data=stations_sel,palette="summer")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.boxplot(x="군/구",y="가격",hue="셀프여부",data=stations_sel,palette="summer")
plt.show()
